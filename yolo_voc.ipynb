# %%
import os
import xml.etree.ElementTree as ET
from xml.dom.minidom import parseString
from PIL import Image 
import numpy as np

def yolo_to_voc(yolo_dir, output_dir, image_dir, image_extension=".jpg"):
    """
    Converts YOLO annotation format to Pascal VOC format.

    :param yolo_dir: Directory containing YOLO .txt files
    :param output_dir: Directory to save VOC .xml files
    :param image_dir: Directory containing image files
    :param image_extension: Image file extension (default is .jpg)
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Define the class list; modify as needed based on actual requirements
    classes = ["fire", "smoke"]  # Ordered according to class_id in YOLO annotations

    for txt_file in os.listdir(yolo_dir):
        if not txt_file.endswith(".txt"):
            continue

        txt_path = os.path.join(yolo_dir, txt_file)
        xml_name = os.path.splitext(txt_file)[0] + ".xml"
        xml_path = os.path.join(output_dir, xml_name)
        image_name = os.path.splitext(txt_file)[0] + image_extension
        image_path = os.path.join(image_dir, image_name)

        # Use PIL to read the image and get its dimensions
        try:
            pil_img = Image.open(image_path)
            image = np.array(pil_img)
            height, width, depth = image.shape
        except Exception as e:
            print(f"Image not found or unable to read: {image_path}. Error: {e}")
            continue

        # Start building the XML
        annotation = ET.Element("annotation")
        ET.SubElement(annotation, "folder").text = os.path.basename(image_dir)
        ET.SubElement(annotation, "filename").text = image_name
        ET.SubElement(annotation, "path").text = image_path
        source = ET.SubElement(annotation, "source")
        ET.SubElement(source, "database").text = "Unknown"

        size = ET.SubElement(annotation, "size")
        ET.SubElement(size, "width").text = str(width)
        ET.SubElement(size, "height").text = str(height)
        ET.SubElement(size, "depth").text = str(depth)

        ET.SubElement(annotation, "segmented").text = "0"

        with open(txt_path, "r") as file:
            for line in file.readlines():
                parts = line.strip().split()
                if len(parts) != 5:
                    print(f"Skipping invalid line in {txt_file}: {line}")
                    continue

                class_id, center_x, center_y, bbox_width, bbox_height = map(float, parts)

                
                class_id = int(class_id)
                if class_id < 0 or class_id >= len(classes):
                    print(f"Class ID {class_id} out of range in {txt_file}: {line}")
                    continue

                # Convert YOLO to VOC
                xmin = int((center_x - bbox_width / 2) * width)
                ymin = int((center_y - bbox_height / 2) * height)
                xmax = int((center_x + bbox_width / 2) * width)
                ymax = int((center_y + bbox_height / 2) * height)

                # Build object node
                obj = ET.SubElement(annotation, "object")
                ET.SubElement(obj, "name").text = classes[class_id]  
                ET.SubElement(obj, "pose").text = "Unspecified"
                ET.SubElement(obj, "truncated").text = "0"
                ET.SubElement(obj, "difficult").text = "0"

                bndbox = ET.SubElement(obj, "bndbox")
                ET.SubElement(bndbox, "xmin").text = str(max(0, xmin))
                ET.SubElement(bndbox, "ymin").text = str(max(0, ymin))
                ET.SubElement(bndbox, "xmax").text = str(min(width, xmax))
                ET.SubElement(bndbox, "ymax").text = str(min(height, ymax))

        # Format and write XML to file
        rough_string = ET.tostring(annotation, 'utf-8')
        reparsed = parseString(rough_string)
        pretty_xml = reparsed.toprettyxml(indent="\t")

        with open(xml_path, "w") as f:
            f.write(pretty_xml)

        print(f"Converted {txt_file} to {xml_path}")


# Usage example (please modify according to the actual path)
yolo_dir = r""  # Replace with YOLO annotation file directory
output_dir = r""  # Replace with the directory of the output XML file
image_dir = r""  # Replace with the directory of the image file

yolo_to_voc(yolo_dir, output_dir, image_dir, image_extension=".jpg")
# Out:
# Converted 00001.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\
txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01420.xml
# Converted 01421.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01421.xml
# Converted 01422.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01422.xml
# Converted 01423.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01423.xml
# Converted 01424.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01424.xml
# Converted 01425.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01425.xml
# Converted 01426.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01426.xml
# Converted 01427.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01427.xml
# Converted 01428.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01428.xml
# Converted 01429.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01429.xml
# Converted 01430.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01430.xml
# Converted 01431.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01431.xml
# Converted 01432.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01432.xml
# Converted 01433.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01433.xml
# Converted 01434.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01434.xml
# Converted 01435.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01435.xml
# Converted 01436.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01436.xml
# Converted 01437.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01437.xml
# Converted 01438.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01438.xml
# Converted 01439.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01439.xml
# Converted 01440.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01440.xml
# Converted 01441.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01441.xml
# Converted 01442.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01442.xml
# Converted 01443.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01443.xml
# Converted 01444.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01444.xml
# Converted 01445.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01445.xml
# Converted 01446.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01446.xml
# Converted 01447.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01447.xml
# Converted 01448.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01448.xml
# Converted 01449.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01449.xml
# Converted 01450.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01450.xml
# Converted 01451.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01451.xml
# Converted 01452.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01452.xml
# Converted 01453.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01453.xml
# Converted 01454.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01454.xml
# Converted 01455.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01455.xml
# Converted 01456.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01456.xml
# Converted 01457.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01457.xml
# Converted 01458.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01458.xml
# Converted 01459.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01459.xml
# Converted 01460.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01460.xml
# Converted 01461.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01461.xml
# Converted 01462.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01462.xml
# Converted 01463.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01463.xml
# Converted 01464.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01464.xml
# Converted 01465.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01465.xml
# Converted 01466.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01466.xml
# Converted 01467.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01467.xml
# Converted 01468.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01468.xml
# Converted 01469.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01469.xml
# Converted 01470.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01470.xml
# Converted 01471.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01471.xml
# Converted 01472.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01472.xml
# Converted 01473.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01473.xml
# Converted 01474.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01474.xml
# Converted 01475.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01475.xml
# Converted 01476.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01476.xml
# Converted 01477.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01477.xml
# Converted 01478.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01478.xml
# Converted 01479.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01479.xml
# Converted 01480.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01480.xml
# Converted 01481.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01481.xml
# Converted 01482.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01482.xml
# Converted 01483.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01483.xml
# Converted 01484.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01484.xml
# Converted 01485.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01485.xml
# Converted 01486.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01486.xml
# Converted 01487.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01487.xml
# Converted 01488.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01488.xml
# Converted 01489.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01489.xml
# Converted 01490.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01490.xml
# Converted 01491.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01491.xml
# Converted 01492.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01492.xml
# Converted 01493.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01493.xml
# Converted 01494.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01494.xml
# Converted 01495.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01495.xml
# Converted 01496.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01496.xml
# Converted 01497.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01497.xml
# Converted 01498.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01498.xml
# Converted 01499.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01499.xml
# Converted 01500.txt to G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\01500.xml

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
display_boxes.py

读取 Pascal VOC 格式的 XML 标注，并在对应图片上绘制边框和类别标签，
支持命令行参数指定输入/输出路径。
"""

import os
import sys
import argparse
import xml.etree.ElementTree as ET

import cv2
import matplotlib.pyplot as plt


def get_annotation_data(xml_path):
    """
    解析 Pascal VOC XML，返回图片尺寸和物体列表。
    每个物体是一个 dict，包含 'name' 和 'bbox'=(xmin, ymin, xmax, ymax)。
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()

    size_node = root.find('size')
    width = int(size_node.find('width').text)
    height = int(size_node.find('height').text)

    objects = []
    for obj in root.findall('object'):
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = int(float(bndbox.find('xmin').text))
        ymin = int(float(bndbox.find('ymin').text))
        xmax = int(float(bndbox.find('xmax').text))
        ymax = int(float(bndbox.find('ymax').text))
        objects.append({
            'name': name,
            'bbox': (xmin, ymin, xmax, ymax)
        })

    return (width, height), objects


def display_bounding_boxes(image_path, xml_path, save_path=None):
    """
    在图片上绘制所有标注框并显示（或保存）结果。
    如果 save_path 不为 None，则保存到磁盘并关闭窗口。
    """
    # 1. 读取图片
    img = cv2.imread(image_path)
    if img is None:
        print(f"错误：无法读取图片 {image_path}", file=sys.stderr)
        return

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # 2. 读取标注
    (w_xml, h_xml), objects = get_annotation_data(xml_path)
    h_img, w_img = img.shape[:2]
    if (w_xml, h_xml) != (w_img, h_img):
        print("警告：XML 中标注尺寸与实际图片尺寸不一致！", file=sys.stderr)
        print(f"  XML 尺寸: {w_xml}×{h_xml}，图片尺寸: {w_img}×{h_img}", file=sys.stderr)

    # 3. 绘制
    plt.figure(figsize=(10, 8))
    plt.imshow(img)
    ax = plt.gca()

    for obj in objects:
        xmin, ymin, xmax, ymax = obj['bbox']
        width = xmax - xmin
        height = ymax - ymin

        rect = plt.Rectangle(
            (xmin, ymin), width, height,
            fill=False, edgecolor='r', linewidth=2
        )
        ax.add_patch(rect)
        ax.text(
            xmin, ymin - 5, obj['name'],
            fontsize=12, color='red',
            verticalalignment='bottom',
            bbox=dict(facecolor='white', alpha=0.7, edgecolor='none', pad=1)
        )

    plt.axis('off')
    plt.tight_layout()

    # 4. 显示或保存
    if save_path:
        plt.savefig(save_path, dpi=200, bbox_inches='tight')
        print(f"已保存结果至 {save_path}")
        plt.close()
    else:
        plt.show()


def parse_args():
    parser = argparse.ArgumentParser(
        description="在 Pascal VOC 格式图片上绘制标注边框"
    )
    parser.add_argument(
        "-i", "--image", required=True,
        help="输入图片路径（JPG/PNG）"
    )
    parser.add_argument(
        "-x", "--xml", required=True,
        help="对应的 Pascal VOC XML 标注文件路径"
    )
    parser.add_argument(
        "-o", "--output", default=None,
        help="输出文件路径（如指定，则保存结果而不弹窗）"
    )
    return parser.parse_args()


if __name__ == "__main__":
    args = parse_args()
    image_url = r"G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\images\00030.jpg"
    xml_url = r"G:\A-desktop\Experiment\datasets2\DM-FFSD\上传EasyDL\Annotations\00030.xml"
    
    # 检查图片和 XML 文件路径
    if not os.path.isfile(image_url):
        print(f"错误：找不到图片文件 {image_url}", file=sys.stderr)
        sys.exit(1)
    if not os.path.isfile(xml_url):
        print(f"错误：找不到 XML 文件 {xml_url}", file=sys.stderr)
        sys.exit(1)

    # 调用函数绘制边框
    display_bounding_boxes(image_url, xml_url, args.output)
# Out:
# usage: ipykernel_launcher.py [-h] -i IMAGE -x XML [-o OUTPUT]
# ipykernel_launcher.py: error: the following arguments are required: -i/--image, -x/--xml
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
